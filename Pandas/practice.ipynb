# %%
import pandas as pd

# %%
df = pd.read_csv("datasets.csv")

# %%
df
# Out:
#                                               name date_of_event   age
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0  \
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district
# ...

# %%
df.shape
# Out:
# (11124, 16)

# %%
df.columns
# Out:
# Index(['name', 'date_of_event', 'age', 'citizenship', 'event_location',
#        'event_location_district', 'event_location_region', 'date_of_death',
#        'gender', 'took_part_in_the_hostilities', 'place_of_residence',
#        'place_of_residence_district', 'type_of_injury', 'ammunition',
#        'killed_by', 'notes'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         name  date_of_event    age  citizenship  event_location
# 0      False          False  False        False           False  \
# 1      False          False  False        False           False
# 2      False          False  False        False           False
# 3      False          False  False        False           False
# 4      False          False  False        False           False
# ...      ...            ...    ...          ...             ...
# 11119  False          False  False        False           False
# 11120  False          False  False        False           False
# 11121  False          False  False        False           False
# 11122  False          False  False        False           False
# 11123  False          False  False        False           False
#
#        event_location_district  event_location_region  date_of_death  gender
# 0                        False                  False          False   False  \
# ...

# %%
df.isnull().sum()
# Out:
# name                               0
# date_of_event                      0
# age                              129
# citizenship                        0
# event_location                     0
# event_location_district            0
# event_location_region              0
# date_of_death                      0
# gender                            20
# took_part_in_the_hostilities    1430
# place_of_residence                68
# place_of_residence_district       68
# type_of_injury                   291
# ammunition                      5253
# killed_by                          0
# notes                            280
# dtype: int64

# %%
null_col = df.isnull().sum()/ df.shape[0]*100
null_col
# Out:
# name                             0.000000
# date_of_event                    0.000000
# age                              1.159655
# citizenship                      0.000000
# event_location                   0.000000
# event_location_district          0.000000
# event_location_region            0.000000
# date_of_death                    0.000000
# gender                           0.179791
# took_part_in_the_hostilities    12.855088
# place_of_residence               0.611291
# place_of_residence_district      0.611291
# type_of_injury                   2.615965
# ammunition                      47.222222
# killed_by                        0.000000
# notes                            2.517080
# dtype: float64

# %%
null_col = null_col.loc[null_col.values > 0]
null_col
# Out:
# age                              1.159655
# gender                           0.179791
# took_part_in_the_hostilities    12.855088
# place_of_residence               0.611291
# place_of_residence_district      0.611291
# type_of_injury                   2.615965
# ammunition                      47.222222
# notes                            2.517080
# dtype: float64

# %%
df = df.drop(null_col.loc[null_col.values > 46].index, axis=1)

# %%
null_col = df.isnull().sum()/ df.shape[0]*100
null_col = null_col.loc[null_col.values > 0]
null_col
# Out:
# age                              1.159655
# gender                           0.179791
# took_part_in_the_hostilities    12.855088
# place_of_residence               0.611291
# place_of_residence_district      0.611291
# type_of_injury                   2.615965
# notes                            2.517080
# dtype: float64

# %%
df['gender'].value_counts()
# Out:
# gender
# M    9681
# F    1423
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].fillna("M")

# %%
df['gender'].value_counts()
# Out:
# gender
# M    9701
# F    1423
# Name: count, dtype: int64

# %%
df['took_part_in_the_hostilities'] = df['took_part_in_the_hostilities'].fillna('Unknown')

# %%
df = df.dropna()

# %%
df
# Out:
#                                               name date_of_event   age
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0  \
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11118                               Marik Gavrilov    2000-10-27  25.0
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
#
#        citizenship     event_location event_location_district
# ...

# %%
df.isnull().sum()
# Out:
# name                            0
# date_of_event                   0
# age                             0
# citizenship                     0
# event_location                  0
# event_location_district         0
# event_location_region           0
# date_of_death                   0
# gender                          0
# took_part_in_the_hostilities    0
# place_of_residence              0
# place_of_residence_district     0
# type_of_injury                  0
# killed_by                       0
# notes                           0
# dtype: int64

# %%
df.select_dtypes(include=object)
# Out:
#                                               name date_of_event  citizenship
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  Palestinian  \
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  Palestinian
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  Palestinian
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  Palestinian
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  Palestinian
# ...                                            ...           ...          ...
# 11118                               Marik Gavrilov    2000-10-27      Israeli
# 11119                             Binyamin Herling    2000-10-19      Israeli
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  Palestinian
# 11121                             Hillel Lieberman    2000-10-07      Israeli
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  Palestinian
#
# ...

# %%
df["date_of_event"]
# Out:
# 0        2023-09-24
# 1        2023-09-24
# 2        2023-09-22
# 3        2023-09-20
# 4        2023-09-19
#             ...
# 11118    2000-10-27
# 11119    2000-10-19
# 11120    2000-10-17
# 11121    2000-10-07
# 11122    2000-10-07
# Name: date_of_event, Length: 10428, dtype: object

# %%
df["date_of_event"] = pd.to_datetime(df["date_of_event"])

# %%
df["date_of_death"]
# Out:
# 0        2023-09-24
# 1        2023-09-24
# 2        2023-09-22
# 3        2023-09-20
# 4        2023-09-19
#             ...
# 11118    2000-10-27
# 11119    2000-10-19
# 11120    2000-10-17
# 11121    2000-10-07
# 11122    2000-10-07
# Name: date_of_death, Length: 10428, dtype: object

# %%
df["date_of_death"] = pd.to_datetime(df["date_of_death"])

# %%
df.select_dtypes(include=object)
# Out:
#                                               name  citizenship
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash  Palestinian  \
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali  Palestinian
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan  Palestinian
# 3                 Durgham Muhammad Yihya al-Akhras  Palestinian
# 4                     Raafat 'Omar Ahmad Khamaisah  Palestinian
# ...                                            ...          ...
# 11118                               Marik Gavrilov      Israeli
# 11119                             Binyamin Herling      Israeli
# 11120                  Farid Musa 'Issa a-Nesasreh  Palestinian
# 11121                             Hillel Lieberman      Israeli
# 11122                    Fahed Mustafa 'Odeh Baker  Palestinian
#
#           event_location event_location_district event_location_region gender
# 0         Nur Shams R.C.                 Tulkarm             West Bank      M  \
# ...

# %%
df.select_dtypes(exclude=object)
# Out:
#       date_of_event   age date_of_death
# 0        2023-09-24  32.0    2023-09-24
# 1        2023-09-24  21.0    2023-09-24
# 2        2023-09-22  16.0    2023-09-22
# 3        2023-09-20  19.0    2023-09-20
# 4        2023-09-19  15.0    2023-09-19
# ...             ...   ...           ...
# 11118    2000-10-27  25.0    2000-10-27
# 11119    2000-10-19  64.0    2000-10-19
# 11120    2000-10-17  28.0    2000-10-17
# 11121    2000-10-07  36.0    2000-10-07
# 11122    2000-10-07  21.0    2000-10-07
#
# [10428 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# name                            0
# date_of_event                   0
# age                             0
# citizenship                     0
# event_location                  0
# event_location_district         0
# event_location_region           0
# date_of_death                   0
# gender                          0
# took_part_in_the_hostilities    0
# place_of_residence              0
# place_of_residence_district     0
# type_of_injury                  0
# killed_by                       0
# notes                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10428 entries, 0 to 11122
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          10428 non-null  object
#  1   date_of_event                 10428 non-null  datetime64[ns]
#  2   age                           10428 non-null  float64
#  3   citizenship                   10428 non-null  object
#  4   event_location                10428 non-null  object
#  5   event_location_district       10428 non-null  object
#  6   event_location_region         10428 non-null  object
#  7   date_of_death                 10428 non-null  datetime64[ns]
#  8   gender                        10428 non-null  object
#  9   took_part_in_the_hostilities  10428 non-null  object
#  10  place_of_residence            10428 non-null  object
#  11  place_of_residence_district   10428 non-null  object
# ...

# %%
df.columns = df.columns.str.title()

# %%
df
# Out:
#                                               Name Date_Of_Event   Age
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0  \
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11118                               Marik Gavrilov    2000-10-27  25.0
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
#
#        Citizenship     Event_Location Event_Location_District
# ...

# %%
df["Citizenship"].value_counts()
# Out:
# Citizenship
# Palestinian    9442
# Israeli         983
# Jordanian         2
# American          1
# Name: count, dtype: int64

# %%
df["Event_Location"].value_counts()
# Out:
# Event_Location
# Gaza City                2112
# Rafah                     796
# Khan Yunis                524
# Jabalya R.C.              459
# Beit Lahiya               437
#                          ...
# Ein Hashlosha               1
# Deir al-'Asal al-Foqa       1
# Beitin                      1
# 'Ein Siniya                 1
# Bidya                       1
# Name: count, Length: 482, dtype: int64

# %%
df["Event_Location_District"].value_counts()
# Out:
# Event_Location_District
# Gaza                    2306
# North Gaza              1787
# Khan Yunis              1354
# Rafah                   1025
# Deir al-Balah            822
# Israel                   650
# Nablus                   562
# Jenin                    448
# Hebron                   324
# Ramallah and al-Bira     320
# Tulkarm                  208
# Bethlehem                173
# East Jerusalem           124
# al-Quds                   83
# Gush Katif                62
# Qalqiliya                 60
# Jericho                   44
# Tubas                     39
# Salfit                    33
# Gaza Strip                 4
# Name: count, dtype: int64

# %%
df["Event_Location_District"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Event_Location_District'>

# %%
df
# Out:
#                                               Name Date_Of_Event   Age
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0  \
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11118                               Marik Gavrilov    2000-10-27  25.0
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
#
#        Citizenship     Event_Location Event_Location_District
# ...
